# %%
import netCDF4
url='http://geoport.whoi.edu/thredds/dodsC/usgs/data2/rsignell/models/maurer.ncml'
nc=netCDF4.Dataset(url).variables

# %%
nc.keys()
# Out:
# [u'time', u'lev', u'lat', u'lon', u'temperature', u'salinity']

# %%
t=nc['temperature'][1,0,::10,::10]
imshow(t)
gca().invert_yaxis()
title('temperature');

# %%
s=nc['salinity'][1,0,::10,::10]
imshow(s,vmin=32.,vmax=36.)
gca().invert_yaxis()
title('salinity');

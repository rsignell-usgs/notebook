# %%
import netCDF4
url='http://geoport-dev.whoi.edu/thredds/dodsC/usgs/data2/rsignell/data/sidescan/mb_geo_backgs10m_geo.tif'
nc=netCDF4.Dataset(url).variables

# %%
nc.keys()
# Out:
# [u'lon0', u'lat0', u'crs0', u'I0B0']

# %%
z=nc['I0B0'][:,:]
lon=nc['lon0'][:]
lat=nc['lat0'][:]

# %%
z.dtype
# Out:
# dtype('int8')

# %%
figure(figsize=(14,10));
imshow(z);
colorbar()
title('INCORRECT');

# %%
figure(figsize=(14,10));
imshow(z.astype(np.uint8))
colorbar()
title('CORRECT');

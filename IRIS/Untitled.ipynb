# %%
# %matplotlib inline

# %%
url = 'http://opendap.oceanobservatories.org/thredds/dodsC/ooi/rsignell-usgs-gov/20161123T152332-CP03ISSM-RID26-07-NUTNRB000-telemetered-nutnr_b_dcl_dark_full_instrument/deployment0001_CP03ISSM-RID26-07-NUTNRB000-telemetered-nutnr_b_dcl_dark_full_instrument.ncml'

# %%
import xarray as xr
b = xr.open_dataset(url)

# %%
b['nitrate_concentration'].plot()

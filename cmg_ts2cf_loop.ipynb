# %% [markdown]
# #Convert existing time series NetCDF files in 4D (T,Z,Y,X) "grid" format to CF-1.6 format

# %% [markdown]
# All the USGS time series data has traditionally been stored in PMEL EPIC-compliant NetCDF files.  These files use EPIC codes for

# %%
import glob
import os
import netCDF4
import StringIO
import pandas as pd
import re

# %%
projs = '''
ARGO_MERCHANT,B. Butman,Argo Merchant Experiment,A moored array deployed after the ARGO MERCHANT ran aground onNantucket Shoals designed to help understand the fate of the spilled oil.
BUZZ_BAY,B. Butman,Currents and Sediment Transport in Buzzards Bay,Investigation of the near-bottom circulation in Buzzards Bay and consequent transport of fine-grained sediments that may be contaminated with PCBs from inner New Bedford Harbor.
CAMP,B. Butman,California Area Monitoring Program (CAMP),A four-year multi-disciplinary field and laboratory study to investigate the sediment transport regime in the vicinity of production drilling rigs in the Santa Barbara Basin
CAPE_COD_BAY,B. Butman,Currents and Sediment Transport in Cape Cod Bay,A pilot study to determine the effect of winter storms on sediment movement at two potential dredge spoil disposal areas.
CC_MISC,B. Butman,Transport studies - Nauset Inlet,Part of a collaborative study of sediment movement in Nauset Inlet.
DEEP_REEF,J. Lacey,Gulf of Mexico - Pinnacles,Pressure data from the Gulf of Mexico
DWDS_106,B. Butman,Sediment Transport at Deep Water Dump Site 106,Near-bottom current measurements to understand the fate and transport of sludge from the New York Metropolitan region discharged at the sea surface.
ECOHAB_II,R. Signell,Ecology of Harmful Algal Blooms (ECOHAB-II),A field program to continue investigating the transport and fate of toxic dinoflagellate blooms in the western Gulf of Maine.
ECOHAB_I,R. Signell,Ecology of Harmful Algal Blooms (ECOHAB-I),A field program to study the transport and fate of toxic dinoflagellate blooms in the western Gulf of Maine.
EUROSTRATAFORM,C. Sherwood,EuroSTRATAFORM,The EuroSTRATAFORM Po and Apennine Sediment Transport and Accumulation (PASTA) experiment was an international study of sediment-transport processes and formation of geological strata in the Adriatic Sea.
FARALLONES,M. Noble,Farallons,Program to measure the currents and circulation on the continental slope off San Francisco CA and thus infer the transport of dredged materialat the newly-established deep-water disposal site.
GB_SED,B. Butman,Georges Bank Current and Sediment Transport Studies,A series of studies to assess environmental hazards to petroleum development in the Georges Bank and New England Shelf region
GLOBEC_GB,R. Schlitz,GLOBEC Georges Bank Program,A moored array program to investigate the circulation and mixing of plankton on Georges Bank.
GLOBEC_GSC,R. Schlitz,GLOBEC Great South Channel Circulation Experiment,A moored array program to investigate the recirculation of water and plankton around Georges Bank
GULF_MAINE,B. Butman,Deep Circulation in the Gulf of Maine,A two-year field study to investigate the deep flow between the major basins in the Gulf of Maine and the effects on the distribution of suspended sediments.
HUDSON_SVALLEY,B. Butman,Circulation and Sediment Transport in the Hudson Shelf Valley,Field experiments have been carried out to understand the transport of sediments and associated contaminants in the Hudson Shelf Valley offshore of New York.
KARIN_RIDGE,M. Noble,Karin Ridge Experiment,Current measurements collected at 2 sites in Karin Ridge Seamount.
LYDONIA_C,B. Butman,Lydonia Canyon Dynamics Experiment,A major field experiment to determine the importance of submarine canyons in sediment transport along and across the continental margin.
MAB_SED,B. Butman,Sediment Transport Observations in the Middle Atlantic Bight,A series of studies to assess environmental hazards to petroleum development in the Middle Atlantic Bight. 
MAMALA_BAY,D. Cacchione,Mamala bay Experiment,Current measurements collected at 350-450 meters in Mamala Bay near Waikiki Beach. 
MBAY_CIRC,R. Signell, Massachusetts Bay Circulation Experiment,Current measurements collected at 6 sites in Massachusetts Bay throughout the year to map the tidal wind and density driven currents. 
MBAY_IWAVE,B. Butman,Massachusetts Bay Internal Wave Experiment,A 1-month 4-element moored array experiment to measure the currents associated with large-amplitude internal waves generated by tidal flow across Stellwagen Bank.
MBAY_LTB,B. Butman,Long-term observations in Massachusetts Bay; Site B-Scituate,Measurements of currents and other oceanographic properties were made to assess the impact of sewage discharge from the proposed outfall site.
MBAY_LT,B. Butman,Long-term observations in Massachusetts Bay; Site A-Boston Harbor,Measurements of currents and other oceanographic properties were made to assess the impact of sewage discharge from the proposed outfall site.
MBAY_STELL,R. Signell,Monitoring on Stellwagen Bank,A year-long series of current measurements on the eastern flank of Stellwagen Bank to document the currents at the mouth of Massachusetts Bay driven by the Maine Coastal current.
MBAY_WEST,B. Butman,Currents and Sediment Transport in Western Massachusetts Bay,A pilot winter-time experiment to investigate circulation and sediment transport. Designed to provide information to aid in citing the new ocean outfall for the Boston sewer system.
MOBILE_BAY,B. Butman,Mobile Bay Study,Measure currents and transport out of Mobile Bay.
MONTEREY_BAY,M. Noble,Monterey Bay National Marine Sanctuary Program,Part of a large multi-disciplinary experiment to characterize the geologic environment and to generate a sediment budget.
MONTEREY_CAN,M. Noble,Monterey Canyon Experiment, A program to determine the mechanisms that govern the circulation within and the transport of sediment and water through Monterey Submarine Canyon.
MYRTLEBEACH,J. Warner,Myrtle Beach Experiment SC,Measurements collected as part of a larger study to understand the physical processes that control the transport of sediments in Long Bay South Carolina. 
NE_SLOPE,B. Butman,Currents on the New England Continental Slope,A study designed to describe the currents and to investigate the transport of sediment from the shelf to the slope. 
OCEANOG_C,B. Butman,Oceanographer Canyon Dynamics Experiment,A field experiment to determine the importance of submarine canyons in sediment transport along and across the continental margin.
ORANGE_COUNTY,M. Noble,Orange County Sanitation District Studies,Observations to monitor coastal ocean process that transport suspended material and associated comtaminants across the shelf
PONCHARTRAIN,R. Signell,Lake Ponchartrain Project,A series of moored array studies to investigate the circulation and particle transport in Lake Pontchartrain.
PV_SHELF04,M. Noble,Palos Verdes Shelf 2004,Additional observations to estimate the quantity and direction of sediment erosion and transport on the shelf near the White Point ocean outfalls.
PV_SHELF07,M. Noble,Palos Verdes Shelf 2007,Follow-up observations to evaluate how often coastal ocean processes move the DDT contaminated sediments near the White Point ocean outfalls.
PV_SHELF,M. Noble,Palos Verdes Shelf Study,Initial observations of currents and circulation near the White Point ocean outfalls determine how often coastal ocean processes move the DDT contaminated sediments in this region.
SAB_SED,B. Butman,Sediment Transport Observations in the Southern Atlantic Bight,A series of studies to assess environmental hazards to petroleum development in the South Atlantic Bight.
SOUTHERN_CAL,M. Noble,Southern California Project,A series of moorings were deployed to understand how coastal ocean processes that move sediments change with location on the shelf.
STRESS,B. Butman,Sediment Transport on Shelves and Slopes (STRESS),Experiment on the California continental margin to investigate storm-driven sediment transport.
WRIGHTSVILLE,R. Thieler,Wrightsville Beach Study, Measurements of bottom currents and waves to investigate the flow field and sediment transport in a rippled scour depression offshore of Wrightsville Beach NC.
DIAMONDSHOALS,J. Warner,Cape Hatteras- Diamond Shoals,This experiment was designed to investigate the ocean circulation and sediment transport dynamics at Diamond Shoals NC.
CHANDELEUR,C. Sherwood,Chandeleur Islands Oceanographic Measurements,A program to measure waves water levels and currents near the Chandeleur Islands Louisiana and adjacent berm construction site.
WFAL,N. Ganju,West Falmouth Harbor Fluxes,Oceanographic and water-quality observations made at six locations in West Falmouth Harbor and Buzzards Bay.
BW2011,N. Ganju, Blackwater 2011, Oceanographic and Water-Quality Measurements made at several sites in 2 watersheds in Blackwater National Wildlife Refuge.
MVCO_11,C. Sherwood, OASIS MVCO 2011, Near-seabed Oceanographic Observations made as part of the 2011 OASIS Project at the MVCO.
HURRIRENE_BB,B. Butman, Observations in Buzzards Bay during and after a Hurricane, Oceanographic data collected in Buzzards Bay MA during Hurricane Irene August 2011.'''

# %%
project = pd.read_csv(StringIO.StringIO(projs.strip()), 
                      sep=",\s*",index_col='project_id',
                      names=['project_id', 'project_pi', 'project_name','project_summary'])
# Out:
# /home/usgs/anaconda/lib/python2.7/site-packages/pandas/io/parsers.py:624: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators; you can avoid this warning by specifying engine='python'.
#   ParserWarning)

# %%
project.ix['PV_SHELF']
# Out:
# project_pi                                                  M. Noble
# project_name                                Palos Verdes Shelf Study
# project_summary    Initial observations of currents and circulati...
# Name: PV_SHELF, dtype: object

# %%
project.ix['PV_SHELF'].ix['project_pi']
# Out:
# 'M. Noble'

# %%
len(project)
# Out:
# 47

# %%
for index,row in project.iterrows():
    print index,row['project_pi']
# Out:
# ARGO_MERCHANT B. Butman
# BUZZ_BAY B. Butman
# CAMP B. Butman
# CAPE_COD_BAY B. Butman
# CC_MISC B. Butman
# DEEP_REEF J. Lacey
# DWDS_106 B. Butman
# ECOHAB_II R. Signell
# ECOHAB_I R. Signell
# EUROSTRATAFORM C. Sherwood
# FARALLONES M. Noble
# GB_SED B. Butman
# GLOBEC_GB R. Schlitz
# GLOBEC_GSC R. Schlitz
# GULF_MAINE B. Butman
# HUDSON_SVALLEY B. Butman
# KARIN_RIDGE M. Noble
# LYDONIA_C B. Butman
# MAB_SED B. Butman
# MAMALA_BAY D. Cacchione
# MBAY_CIRC R. Signell
# MBAY_IWAVE B. Butman
# MBAY_LTB B. Butman
# MBAY_LT B. Butman
# MBAY_STELL R. Signell
# MBAY_WEST B. Butman
# MOBILE_BAY B. Butman
# MONTEREY_BAY M. Noble
# MONTEREY_CAN M. Noble
# MYRTLEBEACH J. Warner
# NE_SLOPE B. Butman
# OCEANOG_C B. Butman
# ORANGE_COUNTY M. Noble
# PONCHARTRAIN R. Signell
# PV_SHELF04 M. Noble
# PV_SHELF07 M. Noble
# PV_SHELF M. Noble
# SAB_SED B. Butman
# SOUTHERN_CAL M. Noble
# STRESS B. Butman
# WRIGHTSVILLE R. Thieler
# DIAMONDSHOALS J. Warner
# CHANDELEUR C. Sherwood
# WFAL N. Ganju
# BW2011 N. Ganju
# MVCO_11 C. Sherwood
# HURRIRENE_BB B. Butman

# %%
""" this is Ellyn's old Matlab code:

function nname=lookup_cf(long_name)
% LOOKUP_CF  Get CF equivalent name for EPIC variable long_name
% return the new name string or [] if there's no equivalent
%

if(strfind(lower(long_name),'temp'))
    nname='sea_water_temperature';
elseif (strfind(lower(long_name),'cond'))
    nname='sea_water_electrical_conductivity';
elseif (strfind(lower(long_name),'sal'))
    nname='sea_water_salinity';
elseif (strfind(lower(long_name),'sigma'))
    nname='sea_water_sigma_theta';
% also have to deal with the min, max std of vels for burst stats files
elseif (strfind(lower(long_name),'east'))
    nname='eastward_sea_water_velocity';
elseif (strfind(lower(long_name),'north'))
    nname='northward_sea_water_velocity';
elseif (strfind(lower(long_name),'vertical'))
    nname='upward_sea_water_velocity';
elseif (strfind(lower(long_name),'pitch'))
    nname='platform_pitch_angle';
elseif (strfind(lower(long_name),'roll'))
    nname='platform_roll_angle';
elseif (strfind(lower(long_name),'head'))
    nname='platform_orientation';
elseif (strfind(lower(long_name),'pres'))
    if ~isempty(strfind(lower(long_name),'dev')) || ~isempty(strfind(lower(long_name),'std'))
        nname=[];
    else
       nname='sea_water_pressure';
    end
elseif (strfind(lower(long_name),'cond'))
    nname='sea_water_electrical_conductivity';
elseif (strfind(lower(long_name),'speed'))
    if (strfind(lower(long_name),'rotor'))
        nname=[];
    else
       nname='sea_water_speed';
    end
elseif (strfind(lower(long_name),'direction'))
    nname='direction_of_sea_water_velocity';
else
    nname=[];
end
disp([long_name ' : ' nname])
""";

# %%
#os.chdir('/usgs/data2/emontgomery/stellwagen/Data/ARGO_MERCHANT')

root_dir='/usgs/data2/emontgomery/stellwagen/Data/'
#root_dir='/usgs/data2/emontgomery/stellwagen/Data/MVCO_11'
odir='/usgs/data2/emontgomery/stellwagen/CF-1.6/'
os.chdir(root_dir)

# %%
# now find all the unique names, long_names & units
names = set()
long_names = set()
units = set()
epic_keys = set()
for path, subdirs, files in os.walk(root_dir):
    for name in files:
        file= os.path.join(path, name)
        try:
            nc=netCDF4.Dataset(file)
            for var in nc.variables.keys():
                names.add(var)
                try:
                    long_names.add(nc.variables[var].long_name)
                except:
                    pass
                try:
                    units.add(nc.variables[var].units)
                except:
                    pass
                try:
                    epic_keys.add(nc.variables[var].epic_key)
                except:
                    pass
                    
        except:
            pass

# %%
names= list(names)
long_names = list(long_names)
units = list(units)
epic_keys = list(epic_keys)

# %%
print len(names)
print len(long_names)
print len(units)
print len(epic_keys)
# Out:
# 509
# 545
# 153
# 0

# %%
# let's use Ellyn's approach of matching substrings in the long_names to deduce standard_names

# %%
# air temp, frtemp, laser temp factor, internal, temp diff
filter(lambda x:re.search(r'temp',x.lower()), long_names)
# Out:
# [u'AIR TEMPERATURE (C)      ',
#  u'instrument Transducer Temp.',
#  u'Air Temperature (degrees C)',
#  u'TEMPERATURE (C)          ',
#  u'FR TEMP     ',
#  u'ADP Transducer Temp.',
#  u'ADCP Transducer Temp.',
#  u'TEMPERATURE (C)',
#  u'Transducer Temp.    ',
#  u'laser temperature factor',
#  u'Transducer Temp.',
#  u'TEMP 1      ',
#  u'TEMP 2      ',
#  u'Temperature',
#  u'internal temperature',
#  u'FRTEMP      ',
#  u'TEMP 2 Q    ',
#  u'TEMP        ',
#  u'TEMP DIFF   ',
#  u'TEMP LP     ',
#  u'Sea Surface Temperature (degrees C)',
#  u'TEMPERATURE ']

# %%
# seconds, second
filter(lambda x:re.search(r'cond',x.lower()), long_names)
# Out:
# [u'SPECIFIC CONDUCTANCE        ',
#  u'CONDUCTIVITY             ',
#  u'Specific conductance',
#  u'SECONDS SINCE START',
#  u'second',
#  u'CONDUCTIVITY',
#  u'SP COND     ',
#  u'COND        ',
#  u'CTD Conductivity       ',
#  u'COND 2      ',
#  u'COND 1      ']

# %%
filter(lambda x:re.search(r'sal',x.lower()), long_names)
# Out:
# [u'SALINITY 2 Q',
#  u'SALINITY 1  ',
#  u'CTD Salinity, PSS-78',
#  u'Salinity',
#  u'SALINITY 2  ',
#  u'SALINITY (PPT)           ',
#  u'SALINITY (PSU)           ',
#  u'SALINITY    ']

# %%
filter(lambda x:re.search(r'sigma',x.lower()), long_names)
# Out:
# [u'SIGMA-THETA (KG/M**3) ',
#  u'SIGMA-T (KG/M**3)        ',
#  u'SIGMA-THETA (KG/M**3)    ',
#  u'SIGMA THETA ']

# %%
# deal with burst data, std dev, resolution velocity, variance
filter(lambda x:re.search(r'east',x.lower()), long_names)
# Out:
# [u'Eastward Velocity       ',
#  u'Eastward Velocity',
#  u'Ratio of variances for burst after points replaced by delgitch: Eastward Velocity',
#  u'EAST        ',
#  u'Maximum Eastward Velocity',
#  u'Minimum Eastward Velocity',
#  u'Eastward Resolution Velocity',
#  u'Std. Dev. of east component',
#  u'Ratio of means for burst after points replaced by delgitch: Eastward Velocity',
#  u'EAST VELOCITY VARIANCE   ',
#  u'Mean Eastward Velocity',
#  u'Eastward Velocity        ',
#  u'Eastward Velocity         ',
#  u'EAST LP     ',
#  u'EAST VELOCITY VARIANCE ',
#  u'Mean Resolution VelocityEastward']

# %%
filter(lambda x:re.search(r'north',x.lower()), long_names)
# Out:
# [u'NORTH       ',
#  u'Northward Velocity        ',
#  u'Std. Dev. of north component',
#  u'Peak Wave Direction (degrees North)',
#  u'Wind Direction (degrees true North)',
#  u'Ratio of means for burst after points replaced by delgitch: Northward Velocity',
#  u'Minimum Northward Velocity',
#  u'Maximum Northward Velocity',
#  u'Peak Wave Direction (degrees true North)',
#  u'Northward Velocity',
#  u'Mean Wave Direction (degrees true North)',
#  u'Mean Resolution VelocityNorthward',
#  u'NORTH VELOCITY VARIANCE ',
#  u'NORTH LP    ',
#  u'Northward Resolution Velocity',
#  u'Mean Northward Velocity',
#  u'Ratio of variances for burst after points replaced by delgitch: Northward Velocity',
#  u'Northward Velocity      ',
#  u'Northward Velocity       ',
#  u'NORTH VELOCITY VARIANCE  ']

# %%
filter(lambda x:re.search(r'vertical',x.lower()), long_names)
# Out:
# [u'Vertical Velocity    ',
#  u'Vertical Velocity        ',
#  u'Ratio of means for burst after points replaced by delgitch: Vertical Velocity',
#  u'Vertical Resolution Velocity',
#  u'Ratio of variances for burst after points replaced by delgitch: Vertical Velocity',
#  u'Vertical Velocity',
#  u'Maximum Vertical Velocity',
#  u'Mean Resolution VelocityVertical',
#  u'Vertical Velocity         ',
#  u'Mean Vertical Velocity',
#  u'Minimum Vertical Velocity']

# %%
# wind, rotor speed
filter(lambda x:re.search(r'speed',x.lower()), long_names)
# Out:
# [u'WIND SPEED (CM/S)        ',
#  u'ROTOR SPEED DIFFERENCE',
#  u'ROTOR SPEED DIFFERENCE  ',
#  u'Current Speed',
#  u'UPPER ROTOR SPEED     ',
#  u'Wind Speed (m/s)',
#  u'CURRENT SPEED (CM/S)      ',
#  u'LOWER ROTOR SPEED  ',
#  u'CURRENT SPEED (CM/S)    ',
#  u'VECTOR SPEED',
#  u'LOWER ROTOR SPEED    ',
#  u'WIND SPEED (M/S) ',
#  u'WIND SPEED (CM/S) ',
#  u'CURRENT SPEED (CM/S)       ',
#  u'ROTOR SPEED             ',
#  u'ROTOR SPEED ']

# %%
# std dev
filter(lambda x:re.search(r'pitch',x.lower()), long_names)
# Out:
# [u'INST Pitch',
#  u'Pitch Std. Dev.          ',
#  u'Standard Deviation of INST Pitch',
#  u'INST Pitch             ']

# %%
filter(lambda x:re.search(r'roll',x.lower()), long_names)
# Out:
# [u'Roll Std. Dev.             ',
#  u'INST Roll             ',
#  u'INST Roll',
#  u'Standard Deviation of INST Roll']

# %%
# std dev
filter(lambda x:re.search(r'heading',x.lower()), long_names)
# Out:
# [u'Median INST Heading             ',
#  u'Heading Std. Dev.        ',
#  u'INST Heading',
#  u'INST Heading             ']

# %%
# std, dev, wave height spectra, barometric, presscheck
pres = filter(lambda x:re.search(r'press',x.lower()), long_names)
pres
# Out:
# [u'STAND.DEV.(PRESS)',
#  u'Pressure at Transducer Head',
#  u'Pressure',
#  u'PRESSURE (PASCALS)',
#  u'PRESSURE (DB)          ',
#  u'STAND. DEV. (PRESS)     ',
#  u'AVERAGE BURST PRESSURE   ',
#  u'Bottom Pressure (psia)           ',
#  u'BAROMETRIC PRESSURE (MB) ',
#  u'AVERAGE BURST PRESSURE  ',
#  u'Pressure-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))',
#  u'STAND. DEV. (PRESS)    ',
#  u'INTERVAL PRESSURE       ',
#  u'Barometric Pressure (mbar)',
#  u'PRESS       ',
#  u'Barometric Pressure (mb)',
#  u'ADCP Pressure at Transducer Head',
#  u'AVERAGE RELATIVE PRESSURE',
#  u'PRESSURE            ',
#  u'Raw pressure Std. Dev.',
#  u'PRESSCHECK  ',
#  u'INTERVAL PRESSURE        ',
#  u'PRESSURE    ']

# %%
filter(lambda x:re.search(r'std|dev',x.lower()), pres)
# Out:
# [u'STAND.DEV.(PRESS)',
#  u'STAND. DEV. (PRESS)     ',
#  u'STAND. DEV. (PRESS)    ',
#  u'Raw pressure Std. Dev.']

# %%
# save only direction and current direction
filter(lambda x:re.search(r'direct',x.lower()), long_names)
# Out:
# [u'beginning of first direction slice, degrees',
#  u'Surface-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))',
#  u'Direction (degrees)',
#  u'Peak Wave Direction (degrees North)',
#  u'Wind Direction (degrees true North)',
#  u'V  DIRECTION',
#  u'Peak Wave Direction (degrees true North)',
#  u'CURRENT DIRECTION (T)      ',
#  u'WIND DIRECTION           ',
#  u'CURRENT DIRECTION (T)     ',
#  u'Pressure-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))',
#  u'WIND DIRECTION STABILITY',
#  u'Mean Wave Direction (degrees true North)',
#  u'Directional Wave Energy Spectrum (mm^2/Hz/degree)',
#  u'Velocity-derived Non-directional Wave Height Spectrum (mm/sqrt(Hz))',
#  u'mean wave direction',
#  u'Direction (degrees T)',
#  u'WIND DIRECTION        ',
#  u'Current Direction',
#  u'CURRENT DIRECTION (T)   ']

# %%
f = open('/usgs/data2/notebook/names.txt','w')
f.write("\n".join(names))
f.close()
f = open('/usgs/data2/notebook/long_names.txt','w')
f.write("\n".join(long_names))
f.close()
f = open('/usgs/data2/notebook/units.txt','w')
f.write("\n".join(units))
f.close()

# %% [markdown]
# ## Create a dictionary with `standard_name` to `NetCDF variable` mapping

# %%
d={}

# %%
d['sea_water_temperature']=['instrument transducer temp.', 'temperature (c)','fr temp',
                            'adp transducer temp.','adcp transducer temp.','transducer temp.','temp 1','temp 2',
                            'temperature','internal temperature','frtemp','temp 2 q','temp','temp lp','sea surface temperature (degrees C)']

# %%
d['sea_water_salinity'] = ['salinity 2 q','salinity 1','ctd salinity, pss-78','salinity','salinity (ppt)','salinity (psu)','salinity']

# %%
d['northward_sea_water_velocity']=['northward velocity','north','mean northward velocity','northward velocity','north lp']

# %%
d['eastward_sea_water_velocity']=['eastward velocity','east','mean eastward velocity','eastward velocity','east lp']

# %%
def grid2dsg(ifile,ofile,coord_vars=['time','time2','depth','lat','lon'],
             project_name=None,project_pi=None,project_summary=None):
    nc = netCDF4.Dataset(ifile)
    id = '%s/%s' % (project_name,ifile.split('.')[0])  
    #id = ifile.split('.')[0]
    vars=nc.variables.keys()
    data_vars = [var for var in vars if var not in coord_vars]
    nt = len(nc.dimensions['time'])
    nz = len(nc.dimensions['depth'])
    
    # create dimensions of output file
    nco = netCDF4.Dataset(ofile,'w',clobber=True)
    nco.createDimension('time',nt)
    if nz > 1:
        nco.createDimension('depth',nz)

    nchar=20
    nco.createDimension('nchar',nchar)
    # create coordinate variables
    time_v = nco.createVariable('time', 'f8', ('time'))
    lon_v = nco.createVariable('lon','f4')
    lat_v = nco.createVariable('lat','f4')
    if nz > 1:
        depth_v = nco.createVariable('depth','f4',dimensions='depth')
    else:
        depth_v = nco.createVariable('depth','f4')

    station_v = nco.createVariable('site','S1',('nchar'))
    # write global attributes
    g_attdict = nc.__dict__
    g_attdict['Conventions'] = 'CF-1.6'
    if nz>1:
        g_attdict['featureType'] = 'timeSeriesProfile'
    else:
        g_attdict['featureType'] = 'timeSeries'

    g_attdict['naming_authority'] = 'gov.usgs'
    g_attdict['id'] = id
    g_attdict['source'] = 'USGS'
    g_attdict['institution'] = 'USGS Woods Hole Coastal and Marine Science Center'
    g_attdict['project'] = 'Coastal and Marine Geology Program'
    g_attdict['title'] = '%s/%s/%s' % (g_attdict['source'],project_name,g_attdict['id'])
    g_attdict['keywords']='Oceans > Ocean Pressure > Water Pressure, Oceans > Ocean Temperature > Water Temperature, Oceans > Salinity/Density > Conductivity, Oceans > Salinity/Density > Salinity'
    g_attdict['keywords_vocabulary']='GCMD Science Keywords'
    g_attdict['standard_name_vocabulary'] = 'CF-1.6'
    g_attdict['creator_email'] = 'rsignell@usgs.gov'
    g_attdict['creator_name'] =  'Rich Signell'
    g_attdict['creator_phone'] = '+1 (508) 548-8700'
    g_attdict['creator_url'] = 'http://www.usgs.gov'
    g_attdict['publisher_email'] = 'emontgomery@usgs.gov'
    g_attdict['publisher_name'] =  'Ellyn Montgomery'
    g_attdict['publisher_phone'] = '+1 (508) 548-8700'
    g_attdict['publisher_url'] = 'http://www.usgs.gov'
    g_attdict['contributor_name'] =  project_pi
    g_attdict['contributor_role'] = 'principalInvestigator' #from esip ACDD
    g_attdict['summary'] = project_summary

    nco.setncatts(g_attdict) 
    # write station variable
    station_v.cf_role = 'timeseries_id'
    station_v.standard_name = 'station_id'
    data = numpy.empty((1,),'S'+repr(nchar))
    data[0] = ifile.split('.')[0]
    station_v[:] = netCDF4.stringtochar(data)

    # write time variable
    time_v.units = 'milliseconds since 1858-11-17 00:00:00 +0:00'
    time_v.standard_name = 'time'
    time_v.calendar = 'gregorian'
    time_v[:] = (np.int64(nc.variables['time'][:])-2400001)*3600*24*1000 + nc.variables['time2'][:]

    # write lon variable
    lon_v.units = 'degree_east'
    lon_v.standard_name = 'longitude'
    lon_v[:] = nc.variables['lon'][:]

    # write lat variable
    lat_v.units = 'degree_north'
    lat_v.standard_name = 'latitude'
    lat_v[:] = nc.variables['lat'][:]

    # write depth variable
    depth_v.units = 'm'
    depth_v.standard_name = 'depth'   
    depth_v.positive = 'down'
    depth_v.axis = 'Z'
    depth_v[:] = nc.variables['depth'][:]


    # create the data variables
    var_v=[]
    for varname in data_vars:
        ncvar = nc.variables[varname]
        # if time series variable
        if size(ncvar) == nt:
            var = nco.createVariable(varname,ncvar.dtype,('time'))
        elif size(ncvar) == nz:
            var = nco.createVariable(varname,ncvar.dtype,('depth'))
        else:
            var = nco.createVariable(varname,ncvar.dtype,('time','depth'))

    #   load old variable attributes and modify if necessary 
        attdict = ncvar.__dict__
    #   if dounpackshort and 'scale_factor' in attdict: del attdict['scale_factor']
      
        attdict['coordinates'] = 'time lon lat depth'

        # assign standard_name if in dictionary
        a =[k for (k, v) in d.iteritems() if attdict['long_name'].strip().lower() in v]
        if len(a)==1: attdict['standard_name']=a[0]
        
        # write variable attributes
        var.setncatts(attdict) 
        # write the data
    #    print ncvar
        var[:] = ncvar[:]
    nco.close()

# %%
root_idir='/usgs/data2/emontgomery/stellwagen/Data/'
#root_dir='/usgs/data2/emontgomery/stellwagen/Data/MVCO_11'
root_odir='/usgs/data2/emontgomery/stellwagen/CF-1.6/'
os.chdir(root_dir)

# %%
types = ('*.nc', '*.cdf')
coord_vars = ['time','time2','depth','lat','lon']
badfiles = []
goodfiles = []
for index,row in project.iterrows():
    idir = os.path.join(root_idir,index)
    os.chdir(idir)
    odir = os.path.join(root_odir,index)
    if not os.path.exists(odir):
        os.makedirs(odir)
    ncfiles = []
    for files in types:
        ncfiles.extend(glob.glob(files))
    print index, len(ncfiles)
    project_name = index
    project_pi = project.ix[index].ix['project_pi']
    project_summary = project.ix[index].ix['project_summary']
    print project_name,project_pi,project_summary
    for ifile in ncfiles:
        ofile = os.path.join(odir,ifile)
        print ifile,ofile
        try:
            grid2dsg(ifile,ofile,coord_vars = coord_vars,
                     project_name = project_name,
                     project_pi = project_pi,
                     project_summary = project_summary)
            goodfiles.append(ifile)
        except:
            badfiles.append(ifile)
# Out:
# ARGO_MERCHANT 6
# ARGO_MERCHANT B. Butman A moored array deployed after the ARGO MERCHANT ran aground onNantucket Shoals designed to help understand the fate of the spilled oil.
# 1211-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ARGO_MERCHANT/1211-A1H.cdf
# 1211-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ARGO_MERCHANT/1211-AA.cdf
# 1211P-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ARGO_MERCHANT/1211P-A.cdf
# 1211P-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ARGO_MERCHANT/1211P-A1H.cdf
# 1211TR-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ARGO_MERCHANT/1211TR-A.cdf
# 1211TR-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ARGO_MERCHANT/1211TR-A1H.cdf
# BUZZ_BAY 81
# BUZZ_BAY B. Butman Investigation of the near-bottom circulation in Buzzards Bay and consequent transport of fine-grained sediments that may be contaminated with PCBs from inner New Bedford Harbor.
# 2631-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2631-A.cdf
# 2631-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2631-A1H.cdf
# 2631DS-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2631DS-A.cdf
# 3001TC-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3001TC-A.cdf
# 2631DS-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2631DS-A1H.cdf
# 2651-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2651-A.cdf
# 2651-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2651-A1H.cdf
# 2651DS-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2651DS-A.cdf
# 3001TC-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3001TC-A1H.cdf
# 2651DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2651DS-A1H.cdf
# 2851-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2851-A.cdf
# 2851-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2851-A1H.cdf
# 2861-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2861-A1H.cdf
# 2861-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2861-AA.cdf
# 2871-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2871-A1H.cdf
# 2871-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2871-AA.cdf
# 2871ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2871ATT-A.cdf
# 3021-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3021-A.cdf
# 2871ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2871ATT-A1H.cdf
# 2881-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2881-A.cdf
# 2881-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2881-A1H.cdf
# 2881ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2881ATT-A.cdf
# 3021-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3021-A1H.cdf
# 2881ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2881ATT-A1H.cdf
# 2881TC-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2881TC-A.cdf
# 3021DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3021DS-A1H.cdf
# 2881TC-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2881TC-A1H.cdf
# 2891-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2891-A1H.cdf
# 2891-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2891-AA.cdf
# 2891ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2891ATT-A.cdf
# 3021DS-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3021DS-A.cdf
# 2891ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2891ATT-A1H.cdf
# 2901-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2901-A.cdf
# 2901-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2901-A1H.cdf
# 2911-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2911-A1H.cdf
# 2911-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2911-AA.cdf
# 2911ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2911ATT-A.cdf
# 3031-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031-A.cdf
# 2911ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2911ATT-A1H.cdf
# 2921-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2921-A1H.cdf
# 2921-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2921-AA.cdf
# 2921ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2921ATT-A.cdf
# 3031-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031-A1H.cdf
# 2921ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2921ATT-A1H.cdf
# 2931-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2931-A.cdf
# 2931-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2931-A1H.cdf
# 2941-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2941-A1H.cdf
# 2941-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2941-AA.cdf
# 2941ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2941ATT-A.cdf
# 3031ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031ATT-A.cdf
# 2941ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2941ATT-A1H.cdf
# 2941TP-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2941TP-A.cdf
# 3041TN-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3041TN-A.cdf
# 2941TP-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2941TP-A1H.cdf
# 2951-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2951-A1H.cdf
# 2951-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2951-AA.cdf
# 2951ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2951ATT-A.cdf
# 3041TN-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3041TN-A1H.cdf
# 2951ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2951ATT-A1H.cdf
# 2981-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2981-A1H.cdf
# 2981-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2981-AA.cdf
# 2991-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2991-A.cdf
# 2991-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2991-A1H.cdf
# 2991ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2991ATT-A.cdf
# 3121-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3121-A.cdf
# 2991ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/2991ATT-A1H.cdf
# 3001-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3001-A.cdf
# 3001-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3001-A1H.cdf
# 3001ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3001ATT-A.cdf
# 3121-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3121-A1H.cdf
# 3001ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3001ATT-A1H.cdf
# 3031ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031ATT-A1H.cdf
# 3031DS-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031DS-A.cdf
# 3121ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3121ATT-A.cdf
# 3031DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031DS-A1H.cdf
# 3031TC-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031TC-A1H.cdf
# 3031TC-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3031TC-AA.cdf
# 3041-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3041-A1H.cdf
# 3041-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3041-AA.cdf
# 3041ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3041ATT-A.cdf
# 3041ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/BUZZ_BAY/3041ATT-A1H.cdf
# CAMP
#  42
# CAMP B. Butman A four-year multi-disciplinary field and laboratory study to investigate the sediment transport regime in the vicinity of production drilling rigs in the Santa Barbara Basin
# 3241-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3241-AA.cdf
# 3241ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3241ATT-A.cdf
# 3241ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3241ATT-A1H.cdf
# 3241TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3241TCT-A.cdf
# 3241TCT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3241TCT-A1H.cdf
# 3242-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3242-A.cdf
# 3242-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3242-A1H.cdf
# 3242ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3242ATT-A.cdf
# 3242ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3242ATT-A1H.cdf
# 3242TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3242TCT-A.cdf
# 3242TCT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3242TCT-A1H.cdf
# 3251-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251-A.cdf
# 3251-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251-A1H.cdf
# 3251ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251ATT-A1H.cdf
# 3251ATT-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251ATT-AA.cdf
# 3251DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251DS-A1H.cdf
# 3251S-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251S-A.cdf
# 3251TC-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251TC-A.cdf
# 3251TCT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3251TCT-A1H.cdf
# 3252-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3252-A1H.cdf
# 3252-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3252-AA.cdf
# 3252ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3252ATT-A1H.cdf
# 3252ATT-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3252ATT-AA.cdf
# 3252TC-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3252TC-A.cdf
# 3252TCT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3252TCT-A1H.cdf
# 3301-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3301-A.cdf
# 3301-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3301-A1H.cdf
# 3301TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3301TCT-A.cdf
# 3302-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3302-A.cdf
# 3302-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3302-A1H.cdf
# 3302TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3302TCT-A.cdf
# 3311-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3311-A.cdf
# 3311-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3311-A1H.cdf
# 3312-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3312-A.cdf
# 3312-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3312-A1H.cdf
# 3312TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3312TCT-A.cdf
# 3321-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3321-A.cdf
# 3321-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3321-A1H.cdf
# 3321TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3321TCT-A.cdf
# 3322-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3322-A.cdf
# 3322-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3322-A1H.cdf
# 3322TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAMP/3322TCT-A.cdf
# CAPE_COD_BAY 34
# CAPE_COD_BAY B. Butman A pilot study to determine the effect of winter storms on sediment movement at two potential dredge spoil disposal areas.
# 3051A-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051A-A.cdf
# 3051A-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051A-A1H.cdf
# 3051ATT-1A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-1A.cdf
# 3051ATT-1A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-1A1H.cdf
# 3051ATT-2A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-2A.cdf
# 3051ATT-2A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-2A1H.cdf
# 3051ATT-3A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-3A.cdf
# 3051ATT-3A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-3A1H.cdf
# 3051ATT-4A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-4A.cdf
# 3051ATT-4A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051ATT-4A1H.cdf
# 3051B-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051B-A.cdf
# 3051B-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051B-A1H.cdf
# 3051C-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051C-A.cdf
# 3051C-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051C-A1H.cdf
# 3051D-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051D-A.cdf
# 3051D-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3051D-A1H.cdf
# 3061-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3061-A.cdf
# 3061-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3061-A1H.cdf
# 3061ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3061ATT-A.cdf
# 3061ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3061ATT-A1H.cdf
# 3071DS-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3071DS-A.cdf
# 3071DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3071DS-A1H.cdf
# 3072-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3072-A.cdf
# 3072-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3072-A1H.cdf
# 3072ATT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3072ATT-A.cdf
# 3072ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3072ATT-A1H.cdf
# 3073-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073-A.cdf
# 3073-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073-A1H.cdf
# 3073ATT-1A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073ATT-1A.cdf
# 3073ATT-1A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073ATT-1A1H.cdf
# 3073ATT-2A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073ATT-2A.cdf
# 3073ATT-2A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073ATT-2A1H.cdf
# 3073LED-1AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073LED-1AA.cdf
# 3073LED-2AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CAPE_COD_BAY/3073LED-2AA.cdf
# CC_MISC 2
# CC_MISC B. Butman Part of a collaborative study of sediment movement in Nauset Inlet.
# 2011-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CC_MISC/2011-A.cdf
# 2021-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CC_MISC/2021-A.cdf
# DEEP_REEF
#  1
# DEEP_REEF J. Lacey Pressure data from the Gulf of Mexico
# 6413pt-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DEEP_REEF/6413pt-a.nc
# DWDS_106 16
# DWDS_106 B. Butman Near-bottom current measurements to understand the fate and transport of sludge from the New York Metropolitan region discharged at the sea surface.
# 3361-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3361-A.cdf
# 3361-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3361-A1H.cdf
# 3362-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3362-A.cdf
# 3362-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3362-A1H.cdf
# 3362ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3362ATT-A1H.cdf
# 3362ATT.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3362ATT.cdf
# 3362CS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3362CS-A1H.cdf
# 3362CS.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3362CS.cdf
# 3371-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3371-A.cdf
# 3371-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3371-A1H.cdf
# 3372-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3372-A.cdf
# 3372-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3372-A1H.cdf
# 3372ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3372ATT-A1H.cdf
# 3372ATT.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3372ATT.cdf
# 3372CS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3372CS-A1H.cdf
# 3372CST-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DWDS_106/3372CST-A.cdf
# ECOHAB_II 111
# ECOHAB_II R. Signell A field program to continue investigating the transport and fate of toxic dinoflagellate blooms in the western Gulf of Maine.
# 6223-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6223-a.nc
# 6166sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6166sc-a.nc
# 6223-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6223-a1h.nc
# 6171tcp-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6171tcp-a.nc
# 6224sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6224sc-a.nc
# 6166sc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6166sc-a1h.nc
# 6224sc-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6224sc-a1h.nc
# 6171tcp-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6171tcp-a1h.nc
# 6225adc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6225adc-a.nc
# 617Apt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/617Apt-a.nc
# 6226-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6226-a.nc
# 5211psd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5211psd-a.nc
# 617Apt-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/617Apt-a1h.nc
# 5211psd-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5211psd-a1h.nc
# 6226-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6226-a1h.nc
# 5211tcp-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5211tcp-a.nc
# 6187-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6187-a1h.nc
# 5211tcp-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5211tcp-a1h.nc
# 6226att-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6226att-a.nc
# 6187att-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6187att-a.nc
# 6226att-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6226att-a1h.nc
# 6226cs-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6226cs-a.nc
# 6226cs-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6226cs-a1h.nc
# 6187att-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6187att-a1h.nc
# 6231mc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6231mc-a.nc
# 6187cs-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6187cs-a.nc
# 6231mc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6231mc-a1h.nc
# 6232s4-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6232s4-a.nc
# 6233-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6233-a.nc
# 6187cs-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6187cs-a1h.nc
# 6233-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6233-a1h.nc
# 6191mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6191mc-a.nc
# 6234sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6234sc-a.nc
# 6191mc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6191mc-a1h.nc
# 6234sc-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6234sc-a1h.nc
# 6201mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6201mc-a.nc
# 6235adc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6235adc-a.nc
# 6236-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6236-a.nc
# 6236-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6236-a1h.nc
# 6201mc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6201mc-a1h.nc
# 6236att-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6236att-a.nc
# 6236att-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6236att-a1h.nc
# 6236cs-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6236cs-a.nc
# 6211mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6211mc-a.nc
# 6236cs-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6236cs-a1h.nc
# 5241adc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5241adc-a.nc
# 6211mc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6211mc-a1h.nc
# 6221mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6221mc-a.nc
# 6221mc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6221mc-a1h.nc
# 6222s4-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6222s4-a.nc
# 6161sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6161sc-a.nc
# 6161sc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6161sc-a1h.nc
# 6163sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6163sc-a.nc
# 6163sc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6163sc-a1h.nc
# 6164sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6164sc-a.nc
# 6164sc-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6164sc-a1h.nc
# 6165sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6165sc-a.nc
# 6165sc-a1h.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6165sc-a1h.nc
# 6181mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6181mc-a.nc
# 6181mc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6181mc-a1h.nc
# 6182s4-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6182s4-a.nc
# 6183-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6183-a.nc
# 6183-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6183-a1h.nc
# 6185sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6185sc-a.nc
# 6185sc-a1h.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6185sc-a1h.nc
# 6186adc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6186adc-a.nc
# 6187-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/6187-a.nc
# 5201sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5201sc-a.cdf
# 5201sc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5201sc-a1h.cdf
# 5202sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5202sc-a.cdf
# 5202sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5202sc-a1h.cdf
# 5203sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5203sc-a.cdf
# 5203sc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5203sc-a1h.cdf
# 5204sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5204sc-a.cdf
# 5204sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5204sc-a1h.cdf
# 5205sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5205sc-a.cdf
# 5205sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5205sc-a1h.cdf
# 5221mc-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5221mc-a.cdf
# 5221mc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5221mc-a1h.cdf
# 5223-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5223-a.cdf
# 5223-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5223-a1h.cdf
# 5223asc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5223asc-a.cdf
# 5223asc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5223asc-a1h.cdf
# 5223bsc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5223bsc-a.cdf
# 5223bsc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5223bsc-a1h.cdf
# 5224-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5224-a.cdf
# 5224-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5224-a1h.cdf
# 5224cs-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5224cs-a.cdf
# 5224cs-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5224cs-a1h.cdf
# 5225asc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5225asc-a.cdf
# 5225asc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5225asc-a1h.cdf
# 5225bsc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5225bsc-a.cdf
# 5225bsc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5225bsc-a1h.cdf
# 5231mc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5231mc-a.cdf
# 5231mc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5231mc-a1h.cdf
# 5233-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5233-a.cdf
# 5233-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5233-a1h.cdf
# 5233sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5233sc-a.cdf
# 5233sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5233sc-a1h.cdf
# 5234-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5234-a.cdf
# 5234-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5234-a1h.cdf
# 5234att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5234att-a.cdf
# 5234att-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5234att-a1h.cdf
# 5251mc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5251mc-a.cdf
# 5251mc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5251mc-a1h.cdf
# 5252sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5252sc-a.cdf
# 5252sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5252sc-a1h.cdf
# 5261att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5261att-a.cdf
# 5261att-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5261att-a1h.cdf
# 5261sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5261sc-a.cdf
# 5261sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_II/5261sc-a1h.cdf
# ECOHAB_I 86
# ECOHAB_I R. Signell A field program to study the transport and fate of toxic dinoflagellate blooms in the western Gulf of Maine.
# 4151-a1hlp.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151-a1hlp.nc
# 4152-a1hlp.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4152-a1hlp.nc
# 4153-a1hlp.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153-a1hlp.nc
# 4161-a1hlp.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161-a1hlp.nc
# 4162-a1hlp.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4162-a1hlp.nc
# 4163-a1hlp.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163-a1hlp.nc
# 4471p-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4471p-a.cdf
# 4471p-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4471p-a1h.cdf
# 4151-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151-a.cdf
# 4491p-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4491p-a.cdf
# 4151-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151-a1h.cdf
# 4491p-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4491p-a1h.cdf
# 4531p-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4531p-a1h.cdf
# 4151att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151att-a.cdf
# 4351att-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4351att-a1h.cdf
# 4151att-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151att-a1h.cdf
# 4151sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151sc-a.cdf
# 4351sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4351sc-a1h.cdf
# 4151sc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4151sc-a1h.cdf
# 4152-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4152-a.cdf
# 4152-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4152-a1h.cdf
# 4152sc-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4152sc-a.cdf
# 4351sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4351sc-a.cdf
# 4152sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4152sc-a1h.cdf
# 4153-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153-a.cdf
# 4153-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153-a1h.cdf
# 4153att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153att-a.cdf
# 4352-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4352-a.cdf
# 4153att-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153att-a1h.cdf
# 4153cs-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153cs-a.cdf
# 4352-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4352-a1h.cdf
# 4153cs-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4153cs-a1h.cdf
# 4161-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161-a.cdf
# 4161-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161-a1h.cdf
# 4161att-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161att-a.cdf
# 4352cs-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4352cs-a.cdf
# 4161att-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161att-a1h.cdf
# 4161sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161sc-a.cdf
# 4361sc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4361sc-a1h.cdf
# 4161sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4161sc-a1h.cdf
# 4162-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4162-a.cdf
# 4162-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4162-a1h.cdf
# 4163-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163-a.cdf
# 4163-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163-a1h.cdf
# 4163att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163att-a.cdf
# 4361sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4361sc-a.cdf
# 4163att-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163att-a1h.cdf
# 4163cs-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163cs-a.cdf
# 4362-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4362-a.cdf
# 4163cs-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4163cs-a1h.cdf
# 4171-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4171-a.cdf
# 4171-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4171-a1h.cdf
# 4181p-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4181p-a.cdf
# 4191-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4191-a1h.cdf
# 4191p-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4191p-a.cdf
# 4331-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4331-a.cdf
# 4331-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4331-a1h.cdf
# 4331sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4331sc-a.cdf
# 4362-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4362-a1h.cdf
# 4331sc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4331sc-a1h.cdf
# 4332-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4332-a.cdf
# 4332-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4332-a1h.cdf
# 4332sc-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4332sc-a.cdf
# 4362cs-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4362cs-a.cdf
# 4332sc-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4332sc-a1h.cdf
# 4333-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4333-a.cdf
# 4333-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4333-a1h.cdf
# 4333cs-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4333cs-a.cdf
# 4362cs-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4362cs-a1h.cdf
# 4333cs-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4333cs-a1h.cdf
# 4341-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4341-a.cdf
# 4341-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4341-a1h.cdf
# 4351-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4351-a.cdf
# 4351-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4351-a1h.cdf
# 4351att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4351att-a.cdf
# 4352cs-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4352cs-a1h.cdf
# 4353-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4353-a.cdf
# 4353-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4353-a1h.cdf
# 4353sc-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4353sc-a.cdf
# 4362t-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4362t-a.cdf
# 4353sc-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4353sc-a1h.cdf
# 4361-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4361-a.cdf
# 4361-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4361-a1h.cdf
# 4361att-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4361att-a.cdf
# 4361att-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4361att-a1h.cdf
# 4362t-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/ECOHAB_I/4362t-a1h.cdf
# EUROSTRATAFORM 4
# EUROSTRATAFORM C. Sherwood The EuroSTRATAFORM Po and Apennine Sediment Transport and Accumulation (PASTA) experiment was an international study of sediment-transport processes and formation of geological strata in the Adriatic Sea.
# 7011adc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/EUROSTRATAFORM/7011adc-a.nc
# 7021mc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/EUROSTRATAFORM/7021mc-a.nc
# 7031adc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/EUROSTRATAFORM/7031adc-a.nc
# 7032mc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/EUROSTRATAFORM/7032mc-a.nc
# FARALLONES
#  41
# FARALLONES M. Noble Program to measure the currents and circulation on the continental slope off San Francisco CA and thus infer the transport of dredged materialat the newly-established deep-water disposal site.
# 5103-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5103-a.nc
# 5104-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5104-a.nc
# 5105-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5105-a.nc
# 5106-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5106-a.nc
# 5107-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5107-a.nc
# 5108-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5108-a.nc
# 5112-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5112-a.nc
# 5113-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5113-a.nc
# 5114-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5114-a.nc
# 5115-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5115-a.nc
# 5123-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5123-a.nc
# 5124-q.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5124-q.nc
# 5125-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5125-a.nc
# 5126-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/5126-a.nc
# 3341-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3341-a.cdf
# 3341-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3341-a1h.cdf
# 3341.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3341.cdf
# 3342-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342-a.cdf
# 3342-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342-a1h.cdf
# 3342.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342.cdf
# 3342att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342att-a.cdf
# 3342att-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342att-a1h.cdf
# 3342tct-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342tct-a.cdf
# 3342tct-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342tct-a1h.cdf
# 3342tct-aq.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3342tct-aq.cdf
# 3351-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3351-a.cdf
# 3351-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3351-a1h.cdf
# 3351.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3351.cdf
# 3352-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352-a.cdf
# 3352-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352-a1h.cdf
# 3352.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352.cdf
# 3352att-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352att-a.cdf
# 3352att-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352att-a1h.cdf
# 3352tct-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352tct-a.cdf
# 3352tct-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3352tct-a1h.cdf
# 3461-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3461-a.cdf
# 3462-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3462-a.cdf
# 3463-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3463-a.cdf
# 3464-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3464-a.cdf
# 3465-q.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3465-q.cdf
# 3465t-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/FARALLONES/3465t-a.cdf
# GB_SED 242
# GB_SED B. Butman A series of studies to assess environmental hazards to petroleum development in the Georges Bank and New England Shelf region
# gba15m.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/gba15m.nc
# gba1mab.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/gba1mab.nc
# gba45m.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/gba45m.nc
# gba75m.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/gba75m.nc
# 1301-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1301-AA.cdf
# 1321-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1321-AA.cdf
# 1012-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1012-A.cdf
# 1321-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1321-A1H.cdf
# 1012-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1012-A1H.cdf
# 1361-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1361-A1H.cdf
# 1013-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1013-A.cdf
# 1361-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1361-AA.cdf
# 1013-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1013-A1H.cdf
# 1441-A1H_d0.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1441-A1H_d0.cdf
# 1013DS-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1013DS-A.cdf
# 1283-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1283-A.cdf
# 1013DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1013DS-A1H.cdf
# 1441-A1H_d1.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1441-A1H_d1.cdf
# 1021-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1021-A.cdf
# 1441-AA_d0.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1441-AA_d0.cdf
# 1021-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1021-A1H.cdf
# 1441-AA_d1.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1441-AA_d1.cdf
# 1022-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1022-A.cdf
# 1442-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1442-A1H.cdf
# 1022-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1022-A1H.cdf
# 1442-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1442-AA.cdf
# 1023-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1023-A.cdf
# 1451-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1451-A1H.cdf
# 1023-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1023-A1H.cdf
# 1451-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1451-AA.cdf
# 1071-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1071-A1H.cdf
# 1452-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1452-A1H.cdf
# 1071-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1071-AA.cdf
# 1452-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1452-AA.cdf
# 107P-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/107P-A.cdf
# 1453-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1453-A1H.cdf
# 107P-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/107P-A1H.cdf
# 1453-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1453-AA.cdf
# 107T-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/107T-A.cdf
# 1491A-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1491A-A1H.cdf
# 107T-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/107T-A1H.cdf
# 1491B-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1491B-A1H.cdf
# 1091-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1091-A1H.cdf
# 1511-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1511-A.cdf
# 1091-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1091-AA.cdf
# 1511-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1511-A1H.cdf
# 1101-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1101-A1H.cdf
# 1512-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1512-A.cdf
# 1101-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1101-AA.cdf
# 1512-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1512-A1H.cdf
# 110T-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/110T-A1H.cdf
# 1513-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1513-A.cdf
# 110T-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/110T-AA.cdf
# 1513-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1513-A1H.cdf
# 111P-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/111P-A.cdf
# 1541-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1541-A.cdf
# 111P-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/111P-A1H.cdf
# 1541-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1541-A1H.cdf
# 1151-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1151-A1H.cdf
# 1541LTN-A_d0.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1541LTN-A_d0.cdf
# 1151-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1151-AA.cdf
# 1541LTN-A_d1.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1541LTN-A_d1.cdf
# 1152-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1152-A1H.cdf
# 1551A-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551A-A.cdf
# 1152-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1152-AA.cdf
# 1551A-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551A-A1H.cdf
# 1161-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1161-A1H.cdf
# 1551B-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551B-A.cdf
# 1161-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1161-AA.cdf
# 1551B-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551B-A1H.cdf
# 116P-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/116P-A1H.cdf
# 1551DS1-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551DS1-A1H.cdf
# 116P-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/116P-AA.cdf
# 1551DS2-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551DS2-A1H.cdf
# 116T-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/116T-A.cdf
# 1551DS3-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1551DS3-A1H.cdf
# 116T-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/116T-A1H.cdf
# 1561A-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561A-A.cdf
# 1181-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1181-A1H.cdf
# 1561A-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561A-A1H.cdf
# 1181-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1181-AA.cdf
# 1561A-R-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561A-R-A.cdf
# 1182-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1182-A1H.cdf
# 1561A-R-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561A-R-A1H.cdf
# 1182-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1182-AA.cdf
# 1561A-TN-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561A-TN-A.cdf
# 1201-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1201-A1H.cdf
# 1561B-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561B-A.cdf
# 1201-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1201-AA.cdf
# 1561B-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561B-A1H.cdf
# 1201P-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1201P-A.cdf
# 1561TN-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1561TN-A1H.cdf
# 1201P-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1201P-A1H.cdf
# 1601-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1601-A.cdf
# 1201TR-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1201TR-A.cdf
# 1283-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1283-A1H.cdf
# 1201TR-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1201TR-A1H.cdf
# 1601-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1601-A1H.cdf
# 1231-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1231-A1H.cdf
# 1601T-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1601T-A.cdf
# 1231-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1231-AA.cdf
# 1601T-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1601T-A1H.cdf
# 1231T-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1231T-A.cdf
# 1602-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1602-A.cdf
# 1231T-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1231T-A1H.cdf
# 1602-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1602-A1H.cdf
# 1251-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1251-A1H.cdf
# 1611-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1611-A.cdf
# 1251-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1251-AA.cdf
# 1611-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1611-A1H.cdf
# 1261-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1261-A1H.cdf
# 1631-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1631-A.cdf
# 1261-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1261-AA.cdf
# 1631-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1631-A1H.cdf
# 1261TP-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1261TP-A.cdf
# 1301-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1301-A1H.cdf
# 1261TP-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1261TP-A1H.cdf
# 1641-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1641-A.cdf
# 1281-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1281-A.cdf
# 1641-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1641-A1H.cdf
# 1281-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1281-A1H.cdf
# 1642-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1642-A.cdf
# 1282-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1282-A.cdf
# 1642-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1642-A1H.cdf
# 1282-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1282-A1H.cdf
# 1371-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1371-A1H.cdf
# 1661-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1661-A.cdf
# 1371-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1371-AA.cdf
# 1661-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1661-A1H.cdf
# 1372-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1372-A1H.cdf
# 1661L-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1661L-A.cdf
# 1372-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1372-AA.cdf
# 1661L-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1661L-A1H.cdf
# 1381-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1381-A.cdf
# 1671-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1671-A1H.cdf
# 1381-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1381-A1H.cdf
# 1671-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1671-AA.cdf
# 1381R-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1381R-A.cdf
# 1701-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1701-A.cdf
# 1381R-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1381R-A1H.cdf
# 1701-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1701-A1H.cdf
# 1391-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1391-A.cdf
# 1713-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1713-A.cdf
# 1391-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1391-A1H.cdf
# 1713TN-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1713TN-A1H.cdf
# 1713-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1713-A1H.cdf
# 1713TN-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1713TN-A.cdf
# 1972-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1972-A.cdf
# 1731-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1731-A.cdf
# 1972-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1972-A1H.cdf
# 1731-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1731-A1H.cdf
# 2561-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2561-A1H.cdf
# 1741-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1741-A.cdf
# 2561-AA.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2561-AA.cdf
# 1741-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1741-A1H.cdf
# 2731-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2731-A1H.cdf
# 1741DS-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1741DS-A.cdf
# 1962-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1962-A.cdf
# 1741DS-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1741DS-A1H.cdf
# 2731-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2731-AA.cdf
# 1751-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1751-A.cdf
# 2731DS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2731DS-A1H.cdf
# 1751-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1751-A1H.cdf
# 2731DS-AA.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2731DS-AA.cdf
# 1751T-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1751T-A.cdf
# 2731LED-1A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2731LED-1A.cdf
# 1751T-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1751T-A1H.cdf
# 2731LED-1A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/2731LED-1A1H.cdf
# 1751TN-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1751TN-A.cdf
# 1962-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1962-A1H.cdf
# 1751TN-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/GB_SED/1751TN-A1H.cdf
# ...
# 3646-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3646-A.cdf
# 3282-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3282-A.cdf
# 3646-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3646-A1H.cdf
# 3282-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3282-A1H.cdf
# 3646ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3646ATT-A.cdf
# 3282ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3282ATT-A.cdf
# 3635-A1H_d0.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635-A1H_d0.cdf
# 3282ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3282ATT-A1H.cdf
# 3646ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3646ATT-A1H.cdf
# 3291-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3291-A.cdf
# 3646CS-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3646CS-A.cdf
# 3291-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3291-A1H.cdf
# 3646CS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3646CS-A1H.cdf
# 3292-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3292-A.cdf
# 3649-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3649-A.cdf
# 3292-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3292-A1H.cdf
# 3649-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3649-A1H.cdf
# 3331-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3331-A.cdf
# 3331-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3331-A1H.cdf
# 3331ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3331ATT-A.cdf
# 3635-A1H_d1.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635-A1H_d1.cdf
# 3331ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3331ATT-A1H.cdf
# 3331TCT-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3331TCT-A.cdf
# 3332-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3332-A.cdf
# 3332-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3332-A1H.cdf
# 3333-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3333-A.cdf
# 3333-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3333-A1H.cdf
# 3333TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3333TCT-A.cdf
# 3334-q.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3334-q.cdf
# 3334-q1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3334-q1h.cdf
# 3635-A_d1.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635-A_d1.cdf
# 3334-q1hlp.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3334-q1hlp.cdf
# 3335-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3335-A.cdf
# 3335-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3335-A1H.cdf
# 3335ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3335ATT-A.cdf
# 3635-A_d0.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635-A_d0.cdf
# 3335ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3335ATT-A1H.cdf
# 3335TCT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3335TCT-A.cdf
# 3621-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3621-A.cdf
# 3621-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3621-A1H.cdf
# 3631-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3631-A.cdf
# 3631-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3631-A1H.cdf
# 3631ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3631ATT-A.cdf
# 3638-1A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3638-1A.cdf
# 3631ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3631ATT-A1H.cdf
# 3631CS-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3631CS-A.cdf
# 3635ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635ATT-A.cdf
# 3631CS-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3631CS-A1H.cdf
# 3632SC-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3632SC-A.cdf
# 3635ATT-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635ATT-A1H.cdf
# 3632SC-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3632SC-A1H.cdf
# 3633SC-A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3633SC-A.cdf
# 3635CS-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3635CS-A1H.cdf
# 3636SC-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3636SC-A.cdf
# 3638-2A.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3638-2A.cdf
# 3636SC-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3636SC-A1H.cdf
# 3637-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3637-A.cdf
# 3637-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3637-A1H.cdf
# 3637ATT-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3637ATT-A.cdf
# 3638-A1H.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3638-A1H.cdf
# 3637ATT-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3637ATT-A1H.cdf
# 3637CS-A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3637CS-A.cdf
# 3638ATT-1A.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3638ATT-1A.cdf
# 3637CS-A1H.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/STRESS/3637CS-A1H.cdf
# WRIGHTSVILLE 13
# WRIGHTSVILLE R. Thieler Measurements of bottom currents and waves to investigate the flow field and sediment transport in a rippled scour depression offshore of Wrightsville Beach NC.
# 4671Atcp-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671Atcp-a.nc
# 4671Btcp-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671Btcp-a.nc
# 4671Ctcp-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671Ctcp-a.nc
# 4671-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671-a.cdf
# 4671p-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671p-a.cdf
# 4671p-a1h.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671p-a1h.cdf
# 4671r-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671r-a1h.cdf
# 4671rot-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671rot-a1h.cdf
# 4671spd-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671spd-a.cdf
# 4671spd-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671spd-a1h.cdf
# 4671tct-a.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671tct-a.cdf
# 4671tct-a1h.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671tct-a1h.cdf
# 4671var-a.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WRIGHTSVILLE/4671var-a.cdf
# DIAMONDSHOALS 39
# DIAMONDSHOALS J. Warner This experiment was designed to investigate the ocean circulation and sediment transport dynamics at Diamond Shoals NC.
# 8531mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8531mc-a.nc
# 8532sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8532sc-a.nc
# 8533pt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8533pt-a.nc
# 8541mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8541mc-a.nc
# 8542p-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8542p-cal.nc
# 8542wh-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8542wh-a.nc
# 8542wh-q.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8542wh-q.nc
# 8543sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8543sc-a.nc
# 8543sc-q.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8543sc-q.nc
# 8544pcb-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8544pcb-cal.nc
# 8544pcs-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8544pcs-cal.nc
# 8545advb-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8545advb-cal.nc
# 8545advs-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8545advs-cal.nc
# 8545advs-calq.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8545advs-calq.nc
# 8551p-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8551p-cal.nc
# 8551wh-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8551wh-a.nc
# 8554sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8554sc-a.nc
# 8562sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8562sc-a.nc
# 8563pt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8563pt-a.nc
# 8571mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8571mc-a.nc
# 8572p-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8572p-cal.nc
# 8572wh-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8572wh-a.nc
# 8573sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8573sc-a.nc
# 8574pcb-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8574pcb-cal.nc
# 8574pcs-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8574pcs-cal.nc
# 8575advb-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8575advb-cal.nc
# 8575advs-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8575advs-cal.nc
# 8576advb-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8576advb-cal.nc
# 8576advs-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8576advs-cal.nc
# 8581wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8581wh-a.nc
# 8582sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8582sc-a.nc
# 8547abs1s.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8547abs1s.cdf
# 8547abs2s.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8547abs2s.cdf
# 8547abs3s.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8547abs3s.cdf
# 8553pen_raw.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8553pen_raw.cdf
# 8558fan_raw.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8558fan_raw.cdf
# 8577abs1s.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8577abs1s.cdf
# 8577abs2s.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8577abs2s.cdf
# 8577abs3s.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/DIAMONDSHOALS/8577abs3s.cdf
# CHANDELEUR
#  16
# CHANDELEUR C. Sherwood A program to measure waves water levels and currents near the Chandeleur Islands Louisiana and adjacent berm construction site.
# 8891wh-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8891wh-a.nc
# 8901wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8901wh-a.nc
# 8911wh-part1-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8911wh-part1-a.nc
# 8911wh-part2-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8911wh-part2-a.nc
# 8911wh-part3-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8911wh-part3-a.nc
# 8921wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8921wh-a.nc
# 8931wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8931wh-a.nc
# 8951wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8951wh-a.nc
# 8971wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8971wh-a.nc
# 8991wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8991wh-a.nc
# 8891p-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8891p-cal.cdf
# 8901p-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8901p-cal.cdf
# 8921p-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8921p-cal.cdf
# 8931p-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8931p-cal.cdf
# 8951p-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8951p-cal.cdf
# 8991p-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/CHANDELEUR/8991p-cal.cdf
# WFAL 28
# WFAL N. Ganju Oceanographic and water-quality observations made at six locations in West Falmouth Harbor and Buzzards Bay.
# 8591wh-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8591wh-a.nc
# 8591whp-cal.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8591whp-cal.nc
# 8592pt-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8592pt-a.nc
# 8593sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8593sc-a.nc
# 8594bl-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8594bl-a.nc
# 8601aqd-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8601aqd-a.nc
# 8602wh-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8602wh-a.nc
# 8603pt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8603pt-a.nc
# 8604sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8604sc-a.nc
# 8621sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8621sc-a.nc
# 8622pt-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8622pt-a.nc
# 8821aqd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8821aqd-a.nc
# 8822pt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8822pt-a.nc
# 8841mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8841mc-a.nc
# 8842mc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8842mc-a.nc
# 8843mc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8843mc-a.nc
# 8851aqd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8851aqd-a.nc
# 8852pt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8852pt-a.nc
# 8862rcm-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8862rcm-a.nc
# 8871aqd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8871aqd-a.nc
# 8872pt-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8872pt-a.nc
# 9001rcm-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/9001rcm-a.nc
# 8602Wvs-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8602Wvs-cal.cdf
# 8831ysi-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8831ysi-cal.cdf
# 8832isus-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8832isus-cal.cdf
# 8861ysi-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8861ysi-cal.cdf
# 8881ysiA-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8881ysiA-cal.cdf
# 8881ysiB-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/WFAL/8881ysiB-cal.cdf
# BW2011
#  12
# BW2011 N. Ganju Oceanographic and Water-Quality Measurements made at several sites in 2 watersheds in Blackwater National Wildlife Refuge.
# 9031ysi-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9031ysi-a.nc
# 9041ysi-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9041ysi-a.nc
# 9051ysi-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9051ysi-a.nc
# 9061ysi-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9061ysi-a.nc
# 9071ysi-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9071ysi-a.nc
# 9081ysi-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9081ysi-a.nc
# 9151ysi-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9151ysi-a.nc
# 9152aqd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9152aqd-a.nc
# 9161ysi-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9161ysi-a.nc
# 9162aqd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9162aqd-a.nc
# 9171eco-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9171eco-a.nc
# 9181eco-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/BW2011/9181eco-a.nc
# MVCO_11
#  13
# MVCO_11 C. Sherwood Near-seabed Oceanographic Observations made as part of the 2011 OASIS Project at the MVCO.
# 9102sc-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9102sc-a.nc
# 9107sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9107sc-a.nc
# 9107sc-tst.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9107sc-tst.nc
# 9107sc-tst2.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9107sc-tst2.nc
# 9111aqd-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9111aqd-a.nc
# 9103HRaqdb-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9103HRaqdb-cal.cdf
# 9103HRaqds-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9103HRaqds-cal.cdf
# 9104pcb-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9104pcb-cal.cdf
# 9104pcs-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9104pcs-cal.cdf
# 9105advb-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9105advb-cal.cdf
# 9105advs-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9105advs-cal.cdf
# 9106advb-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9106advb-cal.cdf
# 9106advs-cal.cdf
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/MVCO_11/9106advs-cal.cdf
# HURRIRENE_BB
#  4
# HURRIRENE_BB B. Butman Oceanographic data collected in Buzzards Bay MA during Hurricane Irene August 2011.
# 9141wh-a.nc /usgs/data2/emontgomery/stellwagen/CF-1.6/HURRIRENE_BB/9141wh-a.nc
# 9142ysi-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/HURRIRENE_BB/9142ysi-a.nc
# 9143sc-a.nc
#  /usgs/data2/emontgomery/stellwagen/CF-1.6/HURRIRENE_BB/9143sc-a.nc
# 9141p-cal.cdf /usgs/data2/emontgomery/stellwagen/CF-1.6/HURRIRENE_BB/9141p-cal.cdf

# %%
len(badfiles)
# Out:
# 166

# %%
len(goodfiles)
# Out:
# 3899

# %%
print badfiles
# Out:
# ['3341.cdf', '3342.cdf', '3351.cdf', '3352.cdf', 'gba15m.nc', 'gba1mab.nc', 'gba45m.nc', 'gba75m.nc', '5881adc-a.nc', '8164adv_1b-cal.nc', '8164adv_2b-cal.nc', '4812.cdf', '4813.cdf', '4201cst-a1h_d1.nc', '4201cst-a_d0.nc', '4201cst-alp_d1.nc', '5071var-a_d1.nc', '5071var-a_d2.nc', '7173advBb-cal.nc', '7674advb-cal.nc', '7674advq-cal.nc', '7752advb-cal.nc', '7752advq-cal.nc', '7774pcab-cal.nc', '7776advb-cal.nc', '7776advq-cal.nc', '7864advb-cal.nc', '7864advq-cal.nc', '7173advAb-cal.cdf', '7173advAq2.cdf', '7173advBb-cal.cdf', '7173advBb-calq.cdf', '7173advb-calq.cdf', '3921var.cdf', '3931att-a.cdf', '3931att-a1h.cdf', '3931cst-a.cdf', '3931cst-a1h.cdf', '3941chek.cdf', '3941tct-a.cdf', '3941var.cdf', '3881chek.cdf', '3951tct-a.cdf', '3881tct-a.cdf', '3881var.cdf', '3821a2-a.cdf', '3821b2-a.cdf', '3821c2-a.cdf', '3821tct-a.cdf', '3921tsc-a.cdf', '3921chek.cdf', '3921tct-a.cdf', '3921tsa-a.cdf', '3921tsb-a.cdf', '4991.cdf', '4992.cdf', '4993.cdf', '5051.cdf', '5054.cdf', '5061.cdf', '5063.cdf', '4983.cdf', '4972.cdf', '4981.cdf', '4982.cdf', '2105769d1-river.nc', '2131010d1-river.nc', '7511aqwp-cal.nc', '7201adwp-cal.nc', 'COAMPSh3-wind.nc', '7221adwp-cal.nc', '7263arwp-cal.nc', '7264abss-cal.nc', '728pcvp-cal5.nc', '7311aqwp-cal.nc', '7321adwp-cal.nc', '7322abss-cal.nc', '7323Aim-cal.nc', '7323Bim-cal.nc', '7331adwp-cal.nc', '7401adwp-cal.nc', '7421adwp-cal.nc', '7441adwp-cal.nc', '7463arwp-cal.nc', '7464abss-cal.nc', '7484abss-cal.nc', '748pcvp-cal6.nc', '7521adwp-cal.nc', '7522abss-cal.nc', '7523Aim-cal.nc', '7523Bim-cal.nc', '7531adwp-cal.nc', '4552tct-a.cdf', '4552tct-a1h.cdf', '4562tct1-a.cdf', '4562tct1-a1h.cdf', '7573adv1b-cal.nc', '7573adv1q-cal.nc', '7573adv2b-cal.nc', '7573adv2q-cal.nc', '7582adv1b-cal.nc', '7582adv1q-cal.nc', '7582adv2b-cal.nc', '7582adv2q-cal.nc', '7583pca-cal.nc', '7583pcab-cal.nc', '7583pcaq-cal.nc', '7584abs-cal.nc', '7574abs-cal.cdf', '8424pcb-cal.nc', '8424pcs-cal.nc', '8425advb-cal.nc', '8511Wvsp-cal.nc', '8426advb-cal.nc', '8444pcb-cal.nc', '8444pcs-cal.nc', '8446advb-cal.nc', '8447advb-cal.nc', '8473pcb-cal.nc', '8473pcs-cal.nc', '8474advb-cal.nc', '8475advb-cal.nc', '8482ls-cal.nc', '8521Wvsp-cal.nc', '8523advb-cal.nc', '5132tct-a.cdf', '4671-a.cdf', '4671r-a1h.cdf', '4671rot-a1h.cdf', '4671spd-a.cdf', '4671spd-a1h.cdf', '4671tct-a.cdf', '4671tct-a1h.cdf', '4671var-a.cdf', '8542p-cal.nc', '8544pcb-cal.nc', '8544pcs-cal.nc', '8545advb-cal.nc', '8551p-cal.nc', '8572p-cal.nc', '8574pcb-cal.nc', '8574pcs-cal.nc', '8575advb-cal.nc', '8576advb-cal.nc', '8547abs1s.cdf', '8547abs2s.cdf', '8547abs3s.cdf', '8553pen_raw.cdf', '8558fan_raw.cdf', '8577abs1s.cdf', '8577abs2s.cdf', '8577abs3s.cdf', '8891p-cal.cdf', '8901p-cal.cdf', '8921p-cal.cdf', '8931p-cal.cdf', '8951p-cal.cdf', '8991p-cal.cdf', '8591whp-cal.nc', '8602Wvs-cal.cdf', '9103HRaqdb-cal.cdf', '9104pcb-cal.cdf', '9104pcs-cal.cdf', '9105advb-cal.cdf', '9106advb-cal.cdf', '9141p-cal.cdf']
